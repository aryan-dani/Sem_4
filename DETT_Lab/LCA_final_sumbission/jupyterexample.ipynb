# %%
import pandas as pd
import numpy as np

# l1 = ["Aryan","Sobaan","hassan"];
# l2 = [80,70,90]
# df = pd.DataFrame({'Names':l1,'Marks':l2})
# df

# data = [("Aryan",80),("Sobaan",85)]
# pdf = pd.DataFrame(data,columns=["Name","Marks"])
# pdf

# data = {'Names':["Aryan","Sobaam"],
#         'Marks':[90,80]}

# df = pd.DataFrame(data)
# df

data = {'Name':['Alice','Bob','Charlie','Sobaan','Himali'],
        'Marks':[85,90,78,70,80],
        'Age':[60,60,55,60,90]}
df = pd.DataFrame(data)

# print("Mean is ",df['Marks'].mean())
# df_imputed = df['Marks'].fillna(df['Marks'].mean())
# df_imputed

# df_dropped = df.dropna(subset='Age')
# df_dropped

from sklearn.preprocessing import MinMaxScaler,StandardScaler
import seaborn as sns
from sklearn.decomposition import PCA

# min = StandardScaler()
cols = ['Marks',"Age"]
# df_normalized = df.copy()
# df_normalized[['Marks']] = min.fit_transform(df[['Marks']])
# df_normalized

# bins = [0,30,70,100]
# labels = ["Young","Adult","Old"]
# df_binned = df.copy()
# df_binned["Age group"] = pd.cut(df['Age'],bins=bins,labels=labels) 
# df_binned

# pc = PCA(n_components=2)
# features = df[cols]
# result = pc.fit_transform(features)
# df1 = pd.DataFrame(data = result,columns=["PC1","PC2"])
# df1

# age = df["Age"]
# marks = df['Marks']
# df_correlation = np.corrcoef(age,marks)[0][1]
# df_correlation

# corr = df[['Marks','Age']].corr(method='pearson')
# print(corr)
# Out:
#           Marks       Age
# Marks  1.000000 -0.011728
# Age   -0.011728  1.000000

# %%
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori,association_rules

transactions = [
    ['milk', 'bread', 'butter'],
    ['bread', 'butter'],
    ['milk', 'bread'],
    ['milk', 'butter'],
    ['bread', 'butter']
]

te = TransactionEncoder()
te_array = te.fit_transform(transactions)
features = pd.DataFrame(data = te_array, columns=te.columns_)
var1 = apriori(features,min_support=0.4,use_colnames=True)
var2 = association_rules(var1,min_threshold=0.6,metric='confidence')
print(var1,var2)
# Out:
#    support         itemsets
# 0      0.8          (bread)
# 1      0.8         (butter)
# 2      0.6           (milk)
# 3      0.6  (bread, butter)
# 4      0.4    (bread, milk)
# 5      0.4   (butter, milk)   antecedents consequents  antecedent support  ...  jaccard  certainty  kulczynski
# 0     (bread)    (butter)                 0.8  ...      0.6  -0.250000    0.750000
# 1    (butter)     (bread)                 0.8  ...      0.6  -0.250000    0.750000
# 2      (milk)     (bread)                 0.6  ...      0.4  -0.666667    0.583333
# 3      (milk)    (butter)                 0.6  ...      0.4  -0.666667    0.583333
#
# [4 rows x 14 columns]

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
# Out:
# The sum of null values in marks column is:  2
